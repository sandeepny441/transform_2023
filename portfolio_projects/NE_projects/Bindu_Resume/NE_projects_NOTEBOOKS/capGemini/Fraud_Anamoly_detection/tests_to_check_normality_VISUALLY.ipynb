# %%
# Histogram 
# QQ Plot
# KDE plot
# Box plot

# %%
import numpy as np
import pandas as pd
from scipy.stats import shapiro, kstest, anderson, normaltest, skew, kurtosis

# Generate normally distributed age data
age = np.random.normal(loc=40, scale=10, size=1000)

# Generate normally distributed savings_amount data
savings_amount = np.random.normal(loc=50000, scale=10000, size=1000)

# Create a DataFrame
df = pd.DataFrame({
    'Age': age,
    'SavingsAmount': savings_amount
})

df
# Out:
#            Age  SavingsAmount
# 0    30.671338   33763.082023
# 1    46.437279   57781.209828
# 2    47.698635   40420.325760
# 3    38.381072   45316.526448
# 4    50.708115   45907.020220
# ..         ...            ...
# 995  44.682314   53446.817316
# 996  50.711940   52265.124207
# 997  50.881001   48508.477944
# 998  43.610473   51686.260720
# 999  56.760950   55383.180857
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt

# Generate your data
# data = [...]

data = df['Age']

# Create histogram
plt.hist(data, bins=30, density=True)
plt.title('Histogram')
plt.show()

# %% [markdown]
# # QQ plot

# %%
import scipy.stats as stats

# Generate your data
# data = [...]

# Create Q-Q plot
stats.probplot(data, dist="norm", plot=plt)
plt.title('Q-Q Plot')
plt.show()

# %% [markdown]
# # Box plot

# %%
# Generate your data
# data = [...]

# Create boxplot
plt.boxplot(data)
plt.title('Box Plot')
plt.show()

# %% [markdown]
# # KDE plot

# %%
import seaborn as sns

# Generate your data
# data = [...]

# Create KDE plot
sns.kdeplot(data)
plt.title('KDE Plot')
plt.show()
