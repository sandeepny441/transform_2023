# %%
import pandas as pd

data = {
  'Text': [
    'Newton\'s laws describe the motion of objects', 
    'Atoms combine to form molecules',
    'Maxwell unified electricity and magnetism', 
    'Photosynthesis converts light into chemical energy',
    'Einstein\'s theory explains gravity as curved spacetime',
    'The Pauli exclusion principle accounts for the periodic table',
    'Quantum mechanics describes physics at small scales'
  ],

  'Label': [
    'Physics',
    'Chemistry', 
    'Physics',
    'Chemistry',
    'Physics',
    'Chemistry',
    'Physics'
  ] 
}

df = pd.DataFrame(data)

df
# Out:
#                                                 Text      Label
# 0       Newton's laws describe the motion of objects    Physics
# 1                    Atoms combine to form molecules  Chemistry
# 2          Maxwell unified electricity and magnetism    Physics
# 3  Photosynthesis converts light into chemical en...  Chemistry
# 4  Einstein's theory explains gravity as curved s...    Physics
# 5  The Pauli exclusion principle accounts for the...  Chemistry
# 6  Quantum mechanics describes physics at small s...    Physics

# %%
import torch
import torch.nn as nn
import pandas as pd

# Load the dataset 
df = pd.DataFrame(data) 

# Convert text to integers using sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['Text']) 

# Convert labels to integers
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
y = le.fit_transform(df['Label'])

# Split data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)


# Convert sparse matrix to dense tensor
X_train = X_train.toarray()
X_test = X_test.toarray() 

X_train = torch.from_numpy(X_train).float()
X_test = torch.from_numpy(X_test).float()

y_train = torch.from_numpy(y_train).long()
y_test = torch.from_numpy(y_test).long()


# MLP model 
class MLP(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size) 
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, output_size)
        
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

input_size = X_train.shape[1] 
hidden_size = 64
output_size = 2 

model = MLP(input_size, hidden_size, output_size)

# Train the model
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

model.train()
for epoch in range(100):
  optimizer.zero_grad()
  
  # Forward pass
  y_pred = model(X_train)
  
  # Compute loss
  loss = criterion(y_pred, y_train)
  
  # Backward pass
  loss.backward()
  
  optimizer.step()

# Evaluate on test data  
model.eval() 
y_pred = model(X_test)
y_pred = torch.argmax(y_pred,dim=1)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.3333333333333333

# %%
df.Label.value_counts()
# Out:
# Physics      4
# Chemistry    3
# Name: Label, dtype: int64

# %%
import torch
import torch.nn as nn
import pandas as pd

# Load the dataset 
df = pd.read_csv("udemy_dataset.csv")

df.drop(columns = "courseid", axis = 1, inplace = True)

df.columns = ["Text", "Label"]


# df = df[df['Label'].isin(["Leadership", "Unity"])]
# Convert text to integers using sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['Text']) 

# Convert labels to integers
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
y = le.fit_transform(df['Label'])

# Split data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)


# Convert sparse matrix to dense tensor
X_train = X_train.toarray()
X_test = X_test.toarray() 

X_train = torch.from_numpy(X_train).float()
X_test = torch.from_numpy(X_test).float()

y_train = torch.from_numpy(y_train).long()
y_test = torch.from_numpy(y_test).long()


# MLP model 
class MLP(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size) 
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, output_size)
        
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

input_size = X_train.shape[1] 
hidden_size = 128
output_size = df.Label.nunique()

model = MLP(input_size, hidden_size, output_size)

# Train the model
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

model.train()
for epoch in range(100):
  optimizer.zero_grad()
  
  # Forward pass
  y_pred = model(X_train)
  
  # Compute loss
  loss = criterion(y_pred, y_train)
  
  # Backward pass
  loss.backward()
  
  optimizer.step()

# Evaluate on test data  
model.eval() 
y_pred = model(X_test)
y_pred = torch.argmax(y_pred,dim=1)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7342465753424657

# %%
df.head()
# Out:
#                                                 Text            Label
# 0  Beginners - How To Create iPhone And iPad Apps...  iOS Development
# 1  C Programming: iOS Development Starts Here!, {...  iOS Development
# 2  Microsoft Excel 2010 Course Beginners/ Interme...            Excel
# 3  Programming Java for Beginners - The Ultimate ...             Java
# 4  Adobe Photoshop for Photographers, {Color Corr...        Photoshop
