# %%
import pandas as pd

# create a sample dataframe
df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
}, index=[5, 4, 3, 2, 1])

df
# Out:
#    A
# 5  1
# 4  2
# 3  3
# 2  4
# 1  5

# %%
df.reset_index()
# Out:
#    index  A
# 0      5  1
# 1      4  2
# 2      3  3
# 3      2  4
# 4      1  5

# %%
df
# Out:
#    A
# 5  1
# 4  2
# 3  3
# 2  4
# 1  5

# %%
df.reset_index(inplace = False)
# Out:
#    level_0  index  A
# 0        0      5  1
# 1        1      4  2
# 2        2      3  3
# 3        3      2  4
# 4        4      1  5

# %%
df
# Out:
#    index  A
# 0      5  1
# 1      4  2
# 2      3  3
# 3      2  4
# 4      1  5

# %%
df
# Out:
#    index  A
# 0      5  1
# 1      4  2
# 2      3  3
# 3      2  4
# 4      1  5

# %%
df.reset_index(drop = True)
# Out:
#    index  A
# 0      5  1
# 1      4  2
# 2      3  3
# 3      2  4
# 4      1  5

# %%
df
# Out:
#    index  A
# 0      5  1
# 1      4  2
# 2      3  3
# 3      2  4
# 4      1  5

# %%
df
# Out:
#    index  A
# 0      5  1
# 1      4  2
# 2      3  3
# 3      2  4
# 4      1  5

# %%
df
# Out:
#    index  A
# 0      5  1
# 1      4  2
# 2      3  3
# 3      2  4
# 4      1  5
