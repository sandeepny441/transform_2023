# %%
import pandas as pd

# create a sample dataframe
df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
}, index=[5, 4, 3, 2, 1])

df
# Out:
#    A
# 5  1
# 4  2
# 3  3
# 2  4
# 1  5

# %%
df.reset_index()
# Out:
#    index  A
# 0      5  1
# 1      4  2
# 2      3  3
# 3      2  4
# 4      1  5

# %%
df
# Out:
#    A
# 5  1
# 4  2
# 3  3
# 2  4
# 1  5

# %%
df.reset_index(inplace = False)
# Out:
#    index  A
# 0      5  1
# 1      4  2
# 2      3  3
# 3      2  4
# 4      1  5

# %%
df
# Out:
#    A
# 5  1
# 4  2
# 3  3
# 2  4
# 1  5

# %%
df
# Out:
#    A
# 5  1
# 4  2
# 3  3
# 2  4
# 1  5

# %%
df.reset_index(drop = True)
# Out:
#    A
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df
# Out:
#    A
# 5  1
# 4  2
# 3  3
# 2  4
# 1  5

# %%
df
# Out:
#    A
# 5  1
# 4  2
# 3  3
# 2  4
# 1  5

# %%
df
# Out:
#    A
# 5  1
# 4  2
# 3  3
# 2  4
# 1  5

# %%
df = pd.DataFrame({"A": [1, 2, 3]}, index=["x", "y", "z"])

df
# Out:
#    A
# x  1
# y  2
# z  3

# %%
df.reindex(["z", "x", "y", "a"])
# Out:
#      A
# z  3.0
# x  1.0
# y  2.0
# a  NaN

# %%
df
# Out:
#    A
# x  1
# y  2
# z  3

# %%
df.reindex(["z", "x", "y", "a"])
# Out:
#      A
# z  3.0
# x  1.0
# y  2.0
# a  NaN

# %%
df
# Out:
#    A
# x  1
# y  2
# z  3

# %%
df = pd.DataFrame({"A": [1, 2, 3, 4, 5]}, index=["x", "y", "z", "a", "b"])

df
# Out:
#    A
# x  1
# y  2
# z  3
# a  4
# b  5

# %%
# drop certain index
df = df.drop(['a', 'b'])

# %%
df
# Out:
#    A
# x  1
# y  2
# z  3

# %%
new_index = ["z", "x", "y", "c", "d"]

# %%
df.reindex(new_index)
# Out:
#      A
# z  3.0
# x  1.0
# y  2.0
# c  NaN
# d  NaN

# %%
df
# Out:
#    A
# x  1
# y  2
# z  3

# %%
# then reindex

df = df.reindex(new_index)

# %%
df
# Out:
#      A
# z  3.0
# x  1.0
# y  2.0
# c  NaN
# d  NaN

# %%
import pandas as pd

# Let's create a simple DataFrame
df = pd.DataFrame({
    'A': ['foo', 'bar', 'baz', 'qux'],
    'B': ['one', 'one', 'two', 'three'],
    'C': ['small', 'large', 'large', 'small'],
    'D': [1, 2, 2, 3],
    'E': [2, 4, 5, 8]
})

df
# Out:
#      A      B      C  D  E
# 0  foo    one  small  1  2
# 1  bar    one  large  2  4
# 2  baz    two  large  2  5
# 3  qux  three  small  3  8

# %%
# Set 'A' column as the index of the DataFrame
df = df.set_index('A')
print("\nDataFrame after setting 'A' as index:")
df
# Out:
# DataFrame after setting 'A' as index:
#          B      C  D  E
# A
# foo    one  small  1  2
# bar    one  large  2  4
# baz    two  large  2  5
# qux  three  small  3  8

# %%
# Set 'A' column as the index of the DataFrame
df.set_index('B')
print("\nDataFrame after setting 'A' as index:")
df
# Out:
# DataFrame after setting 'A' as index:
#          B      C  D  E
# A
# foo    one  small  1  2
# bar    one  large  2  4
# baz    two  large  2  5
# qux  three  small  3  8

# %%
# Set 'A' column as the index of the DataFrame
df = df.set_index('B')
print("\nDataFrame after setting 'A' as index:")
df
# Out:
# DataFrame after setting 'A' as index:
#            C  D  E
# B
# one    small  1  2
# one    large  2  4
# two    large  2  5
# three  small  3  8

# %%
df
# Out:
#            C  D  E
# B
# one    small  1  2
# one    large  2  4
# two    large  2  5
# three  small  3  8

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#        B      C  D  E
# 0    one  small  1  2
# 1    one  large  2  4
# 2    two  large  2  5
# 3  three  small  3  8

# %%
df.set_index('B')
# Out:
#            C  D  E
# B
# one    small  1  2
# one    large  2  4
# two    large  2  5
# three  small  3  8

# %%
df
# Out:
#        B      C  D  E
# 0    one  small  1  2
# 1    one  large  2  4
# 2    two  large  2  5
# 3  three  small  3  8

# %%
df = df.set_index('B')

# %%
df
# Out:
#            C  D  E
# B
# one    small  1  2
# one    large  2  4
# two    large  2  5
# three  small  3  8

# %%
df.set_index('C', append=True, inplace=True)
df
# Out:
#              D  E
# B     C
# one   small  1  2
#       large  2  4
# two   large  2  5
# three small  3  8
